# %%
from datadealing.dataloader import DataLoader
from datasets.datasets import data_to_load, data_timepoints
from models import *

# Create dataloader (same as you used for GNN)
dataloader = DataLoader(
    raw_data=data_to_load,
    data_timepoints=data_timepoints,
    val_ratio=0.2,
    test_ratio=0.2,
    standardization_method='zscore',
    window_size=4,
    include_weeks=True,
    graph_type='identity',
    threshold=0
)

# Initialize models
lr_model = LinearRegressionModel(dataloader, updates=True)
rf_model = RandomForestModel(dataloader, n_estimators=100, updates=True)
xgb_model = XGBoostModel(dataloader, n_estimators=1000, 
                         learning_rate=0.05, 
                         max_depth = 8,
                         subsample = 0.8,
                         colsample_bytree = 0.8,
                         updates=True)

# Train models
print("Training Linear Regression...")
lr_model.train()

print("Training Random Forest...")
rf_model.train()

print("Training XGBoost...")
xgb_model.train()

# Evaluate models
print("Evaluating models...")
lr_model.evaluate()
rf_model.evaluate()
xgb_model.evaluate()

# Compare results
print(f"Linear Regression RMSE: {lr_model.testing_history['rmse']:.4f}")
print(f"Random Forest RMSE: {rf_model.testing_history['rmse']:.4f}")
print(f"XGBoost RMSE: {xgb_model.testing_history['rmse']:.4f}")

# Plot predictions for Budapest (county_idx=4)
lr_model.plot_predictions(county_idx=4)
rf_model.plot_predictions(county_idx=4)
xgb_model.plot_predictions(county_idx=4)
# Out:
# ✅ Created 5 temporal features
# Time 4: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 5: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 6: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 7: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 8: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 9: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 10: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 11: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 12: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 13: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 14: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 15: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 16: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 17: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 18: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 19: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 20: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 21: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 22: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 23: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 24: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 25: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 26: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 27: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 28: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 29: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 30: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 31: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 32: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 33: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 34: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 35: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 36: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 37: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 38: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 39: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 40: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 41: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 42: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 43: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 44: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 45: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 46: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 47: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 48: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 49: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 50: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 51: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 52: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 53: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 54: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 55: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 56: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 57: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 58: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 59: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 60: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 61: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 62: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 63: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 64: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 65: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 66: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 67: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 68: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 69: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 70: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 71: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 72: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 73: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 74: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 75: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 76: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 77: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 78: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 79: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 80: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 81: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 82: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 83: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 84: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 85: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 86: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 87: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 88: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 89: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 90: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 91: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 92: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 93: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 94: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 95: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 96: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 97: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 98: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 99: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 100: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 101: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 102: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 103: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 104: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 105: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 106: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 107: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 108: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 109: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 110: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 111: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 112: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 113: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 114: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 115: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 116: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 117: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 118: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 119: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 120: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 121: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 122: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 123: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 124: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 125: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 126: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 127: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 128: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 129: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 130: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 131: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 132: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 133: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 134: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 135: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 136: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 137: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 138: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 139: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 140: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 141: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 142: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 143: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 144: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 145: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 146: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 147: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 148: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 149: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 150: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 151: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 152: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 153: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 154: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 155: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 156: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 157: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 158: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 159: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 160: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 161: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 162: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 163: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 164: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 165: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 166: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 167: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 168: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 169: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 170: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 171: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 172: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 173: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 174: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 175: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 176: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 177: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 178: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 179: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 180: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 181: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 182: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 183: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 184: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 185: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 186: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 187: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 188: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 189: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 190: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 191: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 192: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 193: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 194: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 195: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 196: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 197: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 198: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 199: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 200: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 201: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 202: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 203: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 204: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 205: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 206: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 207: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 208: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 209: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 210: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 211: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 212: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 213: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 214: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 215: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 216: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 217: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 218: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 219: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 220: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 221: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 222: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 223: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 224: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 225: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 226: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 227: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 228: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 229: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 230: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 231: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 232: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 233: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 234: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 235: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 236: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 237: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 238: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 239: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 240: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 241: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 242: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 243: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 244: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 245: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 246: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 247: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 248: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 249: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 250: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 251: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 252: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 253: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 254: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 255: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 256: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 257: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 258: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 259: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 260: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 261: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 262: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 263: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 264: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 265: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 266: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 267: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 268: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 269: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 270: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 271: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 272: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 273: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 274: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 275: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 276: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 277: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 278: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 279: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 280: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 281: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 282: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 283: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 284: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 285: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 286: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 287: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 288: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 289: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 290: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 291: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 292: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 293: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 294: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 295: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 296: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 297: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 298: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 299: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 300: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 301: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 302: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 303: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 304: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 305: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 306: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 307: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 308: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 309: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 310: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 311: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 312: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 313: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 314: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 315: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 316: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 317: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 318: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 319: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 320: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 321: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 322: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 323: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 324: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 325: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 326: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 327: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 328: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 329: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 330: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 331: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 332: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 333: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 334: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 335: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 336: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 337: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 338: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 339: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 340: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 341: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 342: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 343: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 344: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 345: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 346: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 347: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 348: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 349: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 350: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 351: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 352: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 353: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 354: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 355: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 356: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 357: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 358: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 359: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 360: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 361: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 362: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 363: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 364: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 365: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 366: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 367: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 368: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 369: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 370: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 371: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 372: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 373: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 374: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 375: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 376: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 377: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 378: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 379: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 380: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 381: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 382: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 383: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 384: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 385: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 386: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 387: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 388: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 389: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 390: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 391: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 392: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 393: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 394: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 395: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 396: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 397: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 398: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 399: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 400: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 401: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 402: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 403: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 404: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 405: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 406: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 407: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 408: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 409: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 410: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 411: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 412: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 413: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 414: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 415: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 416: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 417: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 418: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 419: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 420: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 421: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 422: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 423: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 424: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 425: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 426: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 427: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 428: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 429: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 430: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 431: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 432: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 433: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 434: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 435: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 436: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 437: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 438: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 439: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 440: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 441: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 442: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 443: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 444: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 445: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 446: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 447: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 448: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 449: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 450: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 451: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 452: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 453: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 454: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 455: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 456: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 457: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 458: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 459: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 460: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 461: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 462: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 463: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 464: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 465: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 466: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 467: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 468: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 469: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 470: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 471: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 472: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 473: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 474: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 475: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 476: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 477: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 478: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 479: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 480: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 481: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 482: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 483: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 484: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 485: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 486: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 487: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 488: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 489: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 490: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 491: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 492: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 493: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 494: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 495: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 496: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 497: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 498: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 499: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 500: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 501: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 502: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 503: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 504: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 505: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 506: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 507: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 508: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 509: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 510: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 511: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 512: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 513: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 514: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 515: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 516: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 517: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 518: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 519: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 520: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# Time 521: case_features shape: (20, 4), temporal shape: (20, 5), combined: (20, 9)
# ✅ Final X_all shape: (518, 20, 9)
# ✅ Final y_all shape: (518, 20)
# ✅ Train data shape: (331, 20, 9)
# ✅ Val data shape: (83, 20, 9)
# ✅ Test data shape: (104, 20, 9)
# ✅ LinearRegression model built
# ✅ RandomForestRegressor model built
# ✅ XGBRegressor model built
# Training Linear Regression...
# Training LinearRegression...
# ✅ Model trained
# Training Random Forest...
# Training RandomForestRegressor...
# ✅ Model trained
# Training XGBoost...
# Training XGBRegressor...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 36
#      33 rf_model.train()
#      35 print("Training XGBoost...")
# ---> 36 xgb_model.train()
#      38 # Evaluate models
#      39 print("Evaluating models...")
#
# File c:\Users\stend\Documents\python_projects\vzv\src\hungary vzv\models\baseline\core.py:62, in VZVHungaryBaselineModel.train(self, epochs, early_stopping_patience, verbose)
#      59 if verbose and self.updates:
#      60     print(f'Training {self.model.__class__.__name__}...')
# ---> 62 self.model.fit(self.X_train, self.y_train)
#      64 if self.updates:
#      65     print('✅ Model trained')
#
# File c:\Users\stend\anaconda3\envs\torchscatterenv\lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File c:\Users\stend\anaconda3\envs\torchscatterenv\lib\site-packages\xgboost\sklearn.py:1170, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1167     obj = None
#    1169 model, metric, params = self._configure_fit(xgb_model, params)
# -> 1170 self._Booster = train(
#    1171     params,
#    1172     train_dmatrix,
#    1173     self.get_num_boosting_rounds(),
#    1174     evals=evals,
#    1175     early_stopping_rounds=self.early_stopping_rounds,
#    1176     evals_result=evals_result,
#    1177     obj=obj,
#    1178     custom_metric=metric,
#    1179     verbose_eval=verbose,
#    1180     xgb_model=model,
#    1181     callbacks=self.callbacks,
#    1182 )
#    1184 self._set_evaluation_result(evals_result)
#    1185 return self
#
# File c:\Users\stend\anaconda3\envs\torchscatterenv\lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File c:\Users\stend\anaconda3\envs\torchscatterenv\lib\site-packages\xgboost\training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File c:\Users\stend\anaconda3\envs\torchscatterenv\lib\site-packages\xgboost\core.py:2101, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
#    2100     _check_call(
# -> 2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
dataloader.train_dataset
# Out:
# [Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20]),
#  Data(x=[20, 4], edge_index=[2, 20], y=[20], edge_weight=[20])]

# %%
# Create dataloader
dataloader = DataLoader(
    raw_data=data_to_load,
    val_ratio=0.2,
    test_ratio=0.2,
    standardization_method='zscore',
    window_size=1
)

# Define parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [4, 6, 8],
    'learning_rate': [0.05, 0.1, 0.15],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0]
}

# Run grid search
grid_search = XGBoostGridSearch(
    dataloader=dataloader,
    param_grid=param_grid,
    verbose=True
)

grid_search.fit()

# Get results
results_df = grid_search.get_results_dataframe()
print("Top 5 results:")
print(results_df.head())

# Get best model
best_model = grid_search.get_best_model()
best_model.evaluate()

# Save results
grid_search.save_results("xgboost_optimization_results.json")
# Out:
# Starting grid search with 108 combinations...
# Using 3-fold cross-validation
# ------------------------------------------------------------
# [1/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 100, 'subsample': 0.8}
#   CV Score: 0.7665
#   Val Score: 0.6564
#   Best So Far: 0.6564
# ----------------------------------------
# [2/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 100, 'subsample': 1.0}
#   CV Score: 0.7741
#   Val Score: 0.6593
#   Best So Far: 0.6564
# ----------------------------------------
# [3/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 200, 'subsample': 0.8}
#   CV Score: 0.7736
#   Val Score: 0.6628
#   Best So Far: 0.6564
# ----------------------------------------
# [4/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 200, 'subsample': 1.0}
#   CV Score: 0.7784
#   Val Score: 0.6690
#   Best So Far: 0.6564
# ----------------------------------------
# [5/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 300, 'subsample': 0.8}
#   CV Score: 0.7759
#   Val Score: 0.6669
#   Best So Far: 0.6564
# ----------------------------------------
# [6/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 300, 'subsample': 1.0}
#   CV Score: 0.7805
#   Val Score: 0.6744
#   Best So Far: 0.6564
# ----------------------------------------
# [7/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 100, 'subsample': 0.8}
#   CV Score: 0.7659
#   Val Score: 0.6587
#   Best So Far: 0.6564
# ----------------------------------------
# [8/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 100, 'subsample': 1.0}
#   CV Score: 0.7810
#   Val Score: 0.6653
#   Best So Far: 0.6564
# ----------------------------------------
# [9/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 200, 'subsample': 0.8}
#   CV Score: 0.7704
#   Val Score: 0.6633
#   Best So Far: 0.6564
# ----------------------------------------
# [10/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 200, 'subsample': 1.0}
#   CV Score: 0.7846
#   Val Score: 0.6695
#   Best So Far: 0.6564
# ----------------------------------------
# [11/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 300, 'subsample': 0.8}
#   CV Score: 0.7709
#   Val Score: 0.6640
#   Best So Far: 0.6564
# ----------------------------------------
# [12/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 300, 'subsample': 1.0}
#   CV Score: 0.7849
#   Val Score: 0.6708
#   Best So Far: 0.6564
# ----------------------------------------
# [13/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 100, 'subsample': 0.8}
#   CV Score: 0.7654
#   Val Score: 0.6536
#   Best So Far: 0.6536
# ----------------------------------------
# [14/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 100, 'subsample': 1.0}
#   CV Score: 0.7822
#   Val Score: 0.6634
#   Best So Far: 0.6536
# ----------------------------------------
# [15/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 200, 'subsample': 0.8}
#   CV Score: 0.7691
#   Val Score: 0.6579
#   Best So Far: 0.6536
# ----------------------------------------
# [16/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 200, 'subsample': 1.0}
#   CV Score: 0.7853
#   Val Score: 0.6657
#   Best So Far: 0.6536
# ----------------------------------------
# [17/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 300, 'subsample': 0.8}
#   CV Score: 0.7695
#   Val Score: 0.6584
#   Best So Far: 0.6536
# ----------------------------------------
# [18/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 300, 'subsample': 1.0}
#   CV Score: 0.7855
#   Val Score: 0.6660
#   Best So Far: 0.6536
# ----------------------------------------
# [19/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 100, 'subsample': 0.8}
#   CV Score: 0.7805
#   Val Score: 0.6769
#   Best So Far: 0.6536
# ----------------------------------------
# [20/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 100, 'subsample': 1.0}
#   CV Score: 0.7833
#   Val Score: 0.6748
#   Best So Far: 0.6536
# ----------------------------------------
# [21/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 200, 'subsample': 0.8}
#   CV Score: 0.7832
#   Val Score: 0.6841
#   Best So Far: 0.6536
# ----------------------------------------
# [22/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 200, 'subsample': 1.0}
#   CV Score: 0.7860
#   Val Score: 0.6817
#   Best So Far: 0.6536
# ----------------------------------------
# [23/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 300, 'subsample': 0.8}
#   CV Score: 0.7836
#   Val Score: 0.6865
#   Best So Far: 0.6536
# ----------------------------------------
# [24/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 300, 'subsample': 1.0}
#   CV Score: 0.7864
#   Val Score: 0.6834
#   Best So Far: 0.6536
# ----------------------------------------
# [25/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100, 'subsample': 0.8}
#   CV Score: 0.7746
#   Val Score: 0.6657
#   Best So Far: 0.6536
# ----------------------------------------
# [26/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100, 'subsample': 1.0}
#   CV Score: 0.7896
#   Val Score: 0.6730
#   Best So Far: 0.6536
# ----------------------------------------
# [27/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200, 'subsample': 0.8}
#   CV Score: 0.7754
#   Val Score: 0.6670
#   Best So Far: 0.6536
# ----------------------------------------
# [28/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200, 'subsample': 1.0}
#   CV Score: 0.7899
#   Val Score: 0.6738
#   Best So Far: 0.6536
# ----------------------------------------
# [29/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 300, 'subsample': 0.8}
#   CV Score: 0.7754
#   Val Score: 0.6671
#   Best So Far: 0.6536
# ----------------------------------------
# [30/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 300, 'subsample': 1.0}
#   CV Score: 0.7899
#   Val Score: 0.6739
#   Best So Far: 0.6536
# ----------------------------------------
# [31/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 100, 'subsample': 0.8}
#   CV Score: 0.7750
#   Val Score: 0.6603
#   Best So Far: 0.6536
# ----------------------------------------
# [32/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 100, 'subsample': 1.0}
#   CV Score: 0.7861
#   Val Score: 0.6617
#   Best So Far: 0.6536
# ----------------------------------------
# [33/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 200, 'subsample': 0.8}
#   CV Score: 0.7753
#   Val Score: 0.6609
#   Best So Far: 0.6536
# ----------------------------------------
# [34/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 200, 'subsample': 1.0}
#   CV Score: 0.7862
#   Val Score: 0.6618
#   Best So Far: 0.6536
# ----------------------------------------
# [35/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 300, 'subsample': 0.8}
#   CV Score: 0.7753
#   Val Score: 0.6609
#   Best So Far: 0.6536
# ----------------------------------------
# [36/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 300, 'subsample': 1.0}
#   CV Score: 0.7862
#   Val Score: 0.6618
#   Best So Far: 0.6536
# ----------------------------------------
# [37/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.15, 'max_depth': 4, 'n_estimators': 100, 'subsample': 0.8}
#   CV Score: 0.7860
#   Val Score: 0.6730
#   Best So Far: 0.6536
# ----------------------------------------
# [38/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.15, 'max_depth': 4, 'n_estimators': 100, 'subsample': 1.0}
#   CV Score: 0.7842
#   Val Score: 0.6806
#   Best So Far: 0.6536
# ----------------------------------------
# [39/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.15, 'max_depth': 4, 'n_estimators': 200, 'subsample': 0.8}
#   CV Score: 0.7872
#   Val Score: 0.6763
#   Best So Far: 0.6536
# ----------------------------------------
# [40/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.15, 'max_depth': 4, 'n_estimators': 200, 'subsample': 1.0}
#   CV Score: 0.7854
#   Val Score: 0.6843
#   Best So Far: 0.6536
# ----------------------------------------
# [41/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.15, 'max_depth': 4, 'n_estimators': 300, 'subsample': 0.8}
#   CV Score: 0.7873
#   Val Score: 0.6768
#   Best So Far: 0.6536
# ----------------------------------------
# [42/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.15, 'max_depth': 4, 'n_estimators': 300, 'subsample': 1.0}
#   CV Score: 0.7855
#   Val Score: 0.6853
#   Best So Far: 0.6536
# ----------------------------------------
# [43/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.15, 'max_depth': 6, 'n_estimators': 100, 'subsample': 0.8}
#   CV Score: 0.7839
#   Val Score: 0.6626
#   Best So Far: 0.6536
# ----------------------------------------
# [44/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.15, 'max_depth': 6, 'n_estimators': 100, 'subsample': 1.0}
#   CV Score: 0.7939
#   Val Score: 0.6704
#   Best So Far: 0.6536
# ----------------------------------------
# [45/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.15, 'max_depth': 6, 'n_estimators': 200, 'subsample': 0.8}
#   CV Score: 0.7840
#   Val Score: 0.6629
#   Best So Far: 0.6536
# ----------------------------------------
# [46/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.15, 'max_depth': 6, 'n_estimators': 200, 'subsample': 1.0}
#   CV Score: 0.7939
#   Val Score: 0.6708
#   Best So Far: 0.6536
# ----------------------------------------
# [47/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.15, 'max_depth': 6, 'n_estimators': 300, 'subsample': 0.8}
#   CV Score: 0.7840
#   Val Score: 0.6629
#   Best So Far: 0.6536
# ----------------------------------------
# [48/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.15, 'max_depth': 6, 'n_estimators': 300, 'subsample': 1.0}
#   CV Score: 0.7939
#   Val Score: 0.6708
#   Best So Far: 0.6536
# ----------------------------------------
# [49/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.15, 'max_depth': 8, 'n_estimators': 100, 'subsample': 0.8}
#   CV Score: 0.7833
#   Val Score: 0.6588
#   Best So Far: 0.6536
# ----------------------------------------
# [50/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.15, 'max_depth': 8, 'n_estimators': 100, 'subsample': 1.0}
#   CV Score: 0.7912
#   Val Score: 0.6713
#   Best So Far: 0.6536
# ----------------------------------------
# [51/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.15, 'max_depth': 8, 'n_estimators': 200, 'subsample': 0.8}
#   CV Score: 0.7833
#   Val Score: 0.6589
#   Best So Far: 0.6536
# ----------------------------------------
# [52/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.15, 'max_depth': 8, 'n_estimators': 200, 'subsample': 1.0}
#   CV Score: 0.7912
#   Val Score: 0.6713
#   Best So Far: 0.6536
# ----------------------------------------
# [53/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.15, 'max_depth': 8, 'n_estimators': 300, 'subsample': 0.8}
#   CV Score: 0.7833
#   Val Score: 0.6589
#   Best So Far: 0.6536
# ----------------------------------------
# [54/108] Testing: {'colsample_bytree': 0.8, 'learning_rate': 0.15, 'max_depth': 8, 'n_estimators': 300, 'subsample': 1.0}
#   CV Score: 0.7912
#   Val Score: 0.6713
#   Best So Far: 0.6536
# ----------------------------------------
# [55/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 100, 'subsample': 0.8}
#   CV Score: 0.7654
#   Val Score: 0.6567
#   Best So Far: 0.6536
# ----------------------------------------
# [56/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 100, 'subsample': 1.0}
#   CV Score: 0.7832
#   Val Score: 0.6636
#   Best So Far: 0.6536
# ----------------------------------------
# [57/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 200, 'subsample': 0.8}
#   CV Score: 0.7728
#   Val Score: 0.6664
#   Best So Far: 0.6536
# ----------------------------------------
# [58/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 200, 'subsample': 1.0}
#   CV Score: 0.7878
#   Val Score: 0.6747
#   Best So Far: 0.6536
# ----------------------------------------
# [59/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 300, 'subsample': 0.8}
#   CV Score: 0.7746
#   Val Score: 0.6705
#   Best So Far: 0.6536
# ----------------------------------------
# [60/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 300, 'subsample': 1.0}
#   CV Score: 0.7896
#   Val Score: 0.6804
#   Best So Far: 0.6536
# ----------------------------------------
# [61/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 100, 'subsample': 0.8}
#   CV Score: 0.7747
#   Val Score: 0.6637
#   Best So Far: 0.6536
# ----------------------------------------
# [62/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 100, 'subsample': 1.0}
#   CV Score: 0.8047
#   Val Score: 0.6781
#   Best So Far: 0.6536
# ----------------------------------------
# [63/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 200, 'subsample': 0.8}
#   CV Score: 0.7792
#   Val Score: 0.6688
#   Best So Far: 0.6536
# ----------------------------------------
# [64/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 200, 'subsample': 1.0}
#   CV Score: 0.8084
#   Val Score: 0.6816
#   Best So Far: 0.6536
# ----------------------------------------
# [65/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 300, 'subsample': 0.8}
#   CV Score: 0.7797
#   Val Score: 0.6698
#   Best So Far: 0.6536
# ----------------------------------------
# [66/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 300, 'subsample': 1.0}
#   CV Score: 0.8087
#   Val Score: 0.6825
#   Best So Far: 0.6536
# ----------------------------------------
# [67/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 100, 'subsample': 0.8}
#   CV Score: 0.7723
#   Val Score: 0.6585
#   Best So Far: 0.6536
# ----------------------------------------
# [68/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 100, 'subsample': 1.0}
#   CV Score: 0.8089
#   Val Score: 0.6903
#   Best So Far: 0.6536
# ----------------------------------------
# [69/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 200, 'subsample': 0.8}
#   CV Score: 0.7760
#   Val Score: 0.6618
#   Best So Far: 0.6536
# ----------------------------------------
# [70/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 200, 'subsample': 1.0}
#   CV Score: 0.8121
#   Val Score: 0.6926
#   Best So Far: 0.6536
# ----------------------------------------
# [71/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 300, 'subsample': 0.8}
#   CV Score: 0.7764
#   Val Score: 0.6623
#   Best So Far: 0.6536
# ----------------------------------------
# [72/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 300, 'subsample': 1.0}
#   CV Score: 0.8123
#   Val Score: 0.6928
#   Best So Far: 0.6536
# ----------------------------------------
# [73/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 100, 'subsample': 0.8}
#   CV Score: 0.7825
#   Val Score: 0.6709
#   Best So Far: 0.6536
# ----------------------------------------
# [74/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 100, 'subsample': 1.0}
#   CV Score: 0.7889
#   Val Score: 0.6759
#   Best So Far: 0.6536
# ----------------------------------------
# [75/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 200, 'subsample': 0.8}
#   CV Score: 0.7846
#   Val Score: 0.6756
#   Best So Far: 0.6536
# ----------------------------------------
# [76/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 200, 'subsample': 1.0}
#   CV Score: 0.7913
#   Val Score: 0.6849
#   Best So Far: 0.6536
# ----------------------------------------
# [77/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 300, 'subsample': 0.8}
#   CV Score: 0.7850
#   Val Score: 0.6770
#   Best So Far: 0.6536
# ----------------------------------------
# [78/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 300, 'subsample': 1.0}
#   CV Score: 0.7917
#   Val Score: 0.6877
#   Best So Far: 0.6536
# ----------------------------------------
# [79/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100, 'subsample': 0.8}
#   CV Score: 0.7856
#   Val Score: 0.6723
#   Best So Far: 0.6536
# ----------------------------------------
# [80/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100, 'subsample': 1.0}
#   CV Score: 0.8045
#   Val Score: 0.6781
#   Best So Far: 0.6536
# ----------------------------------------
# [81/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200, 'subsample': 0.8}
#   CV Score: 0.7863
#   Val Score: 0.6730
#   Best So Far: 0.6536
# ----------------------------------------
# [82/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200, 'subsample': 1.0}
#   CV Score: 0.8048
#   Val Score: 0.6793
#   Best So Far: 0.6536
# ----------------------------------------
# [83/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 300, 'subsample': 0.8}
#   CV Score: 0.7863
#   Val Score: 0.6731
#   Best So Far: 0.6536
# ----------------------------------------
# [84/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 300, 'subsample': 1.0}
#   CV Score: 0.8049
#   Val Score: 0.6794
#   Best So Far: 0.6536
# ----------------------------------------
# [85/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 100, 'subsample': 0.8}
#   CV Score: 0.7855
#   Val Score: 0.6712
#   Best So Far: 0.6536
# ----------------------------------------
# [86/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 100, 'subsample': 1.0}
#   CV Score: 0.8164
#   Val Score: 0.6937
#   Best So Far: 0.6536
# ----------------------------------------
# [87/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 200, 'subsample': 0.8}
#   CV Score: 0.7858
#   Val Score: 0.6717
#   Best So Far: 0.6536
# ----------------------------------------
# [88/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 200, 'subsample': 1.0}
#   CV Score: 0.8165
#   Val Score: 0.6939
#   Best So Far: 0.6536
# ----------------------------------------
# [89/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 300, 'subsample': 0.8}
#   CV Score: 0.7858
#   Val Score: 0.6717
#   Best So Far: 0.6536
# ----------------------------------------
# [90/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 300, 'subsample': 1.0}
#   CV Score: 0.8165
#   Val Score: 0.6939
#   Best So Far: 0.6536
# ----------------------------------------
# [91/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.15, 'max_depth': 4, 'n_estimators': 100, 'subsample': 0.8}
#   CV Score: 0.7950
#   Val Score: 0.6747
#   Best So Far: 0.6536
# ----------------------------------------
# [92/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.15, 'max_depth': 4, 'n_estimators': 100, 'subsample': 1.0}
#   CV Score: 0.7910
#   Val Score: 0.6828
#   Best So Far: 0.6536
# ----------------------------------------
# [93/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.15, 'max_depth': 4, 'n_estimators': 200, 'subsample': 0.8}
#   CV Score: 0.7960
#   Val Score: 0.6770
#   Best So Far: 0.6536
# ----------------------------------------
# [94/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.15, 'max_depth': 4, 'n_estimators': 200, 'subsample': 1.0}
#   CV Score: 0.7925
#   Val Score: 0.6859
#   Best So Far: 0.6536
# ----------------------------------------
# [95/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.15, 'max_depth': 4, 'n_estimators': 300, 'subsample': 0.8}
#   CV Score: 0.7961
#   Val Score: 0.6772
#   Best So Far: 0.6536
# ----------------------------------------
# [96/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.15, 'max_depth': 4, 'n_estimators': 300, 'subsample': 1.0}
#   CV Score: 0.7925
#   Val Score: 0.6864
#   Best So Far: 0.6536
# ----------------------------------------
# [97/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.15, 'max_depth': 6, 'n_estimators': 100, 'subsample': 0.8}
#   CV Score: 0.7904
#   Val Score: 0.6774
#   Best So Far: 0.6536
# ----------------------------------------
# [98/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.15, 'max_depth': 6, 'n_estimators': 100, 'subsample': 1.0}
#   CV Score: 0.8067
#   Val Score: 0.6753
#   Best So Far: 0.6536
# ----------------------------------------
# [99/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.15, 'max_depth': 6, 'n_estimators': 200, 'subsample': 0.8}
#   CV Score: 0.7905
#   Val Score: 0.6775
#   Best So Far: 0.6536
# ----------------------------------------
# [100/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.15, 'max_depth': 6, 'n_estimators': 200, 'subsample': 1.0}
#   CV Score: 0.8067
#   Val Score: 0.6756
#   Best So Far: 0.6536
# ----------------------------------------
# [101/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.15, 'max_depth': 6, 'n_estimators': 300, 'subsample': 0.8}
#   CV Score: 0.7905
#   Val Score: 0.6775
#   Best So Far: 0.6536
# ----------------------------------------
# [102/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.15, 'max_depth': 6, 'n_estimators': 300, 'subsample': 1.0}
#   CV Score: 0.8067
#   Val Score: 0.6756
#   Best So Far: 0.6536
# ----------------------------------------
# [103/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.15, 'max_depth': 8, 'n_estimators': 100, 'subsample': 0.8}
#   CV Score: 0.7931
#   Val Score: 0.6772
#   Best So Far: 0.6536
# ----------------------------------------
# [104/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.15, 'max_depth': 8, 'n_estimators': 100, 'subsample': 1.0}
#   CV Score: 0.8124
#   Val Score: 0.6947
#   Best So Far: 0.6536
# ----------------------------------------
# [105/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.15, 'max_depth': 8, 'n_estimators': 200, 'subsample': 0.8}
#   CV Score: 0.7931
#   Val Score: 0.6772
#   Best So Far: 0.6536
# ----------------------------------------
# [106/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.15, 'max_depth': 8, 'n_estimators': 200, 'subsample': 1.0}
#   CV Score: 0.8124
#   Val Score: 0.6948
#   Best So Far: 0.6536
# ----------------------------------------
# [107/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.15, 'max_depth': 8, 'n_estimators': 300, 'subsample': 0.8}
#   CV Score: 0.7931
#   Val Score: 0.6772
#   Best So Far: 0.6536
# ----------------------------------------
# [108/108] Testing: {'colsample_bytree': 1.0, 'learning_rate': 0.15, 'max_depth': 8, 'n_estimators': 300, 'subsample': 1.0}
#   CV Score: 0.8124
#   Val Score: 0.6948
#   Best So Far: 0.6536
# ----------------------------------------
#
# Best parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 100, 'subsample': 0.8}
# Best score: 0.6536
# Top 5 results:
#     mean_cv_score  std_cv_score  val_score  training_time  colsample_bytree  \
# 12       0.765446      0.062397   0.653649       5.142644               0.8
# 0        0.766496      0.063938   0.656442       2.371862               0.8
# 54       0.765361      0.070120   0.656737       2.147928               1.0
# 14       0.769099      0.063392   0.657860      10.650079               0.8
# 16       0.769455      0.063465   0.658365      15.229053               0.8
#
#     learning_rate  max_depth  n_estimators  subsample
# 12           0.05          8           100        0.8
# 0            0.05          4           100        0.8
# 54           0.05          4           100        0.8
# 14           0.05          8           200        0.8
# 16           0.05          8           300        0.8
# ✅ XGBRegressor model built
# ✅ Model tested
